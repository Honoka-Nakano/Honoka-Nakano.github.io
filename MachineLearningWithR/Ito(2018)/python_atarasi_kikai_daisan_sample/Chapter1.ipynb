# %% [markdown]
# # 第1章 機械学習の準備

# %% [markdown]
# ## 1.1 機械学習について

# %% [markdown]
# ## 1.2 Python のインストール

# %% [markdown]
# ## 1.3 Jupyter Notebook

# %%
1 / 3
# Out:
# 0.3333333333333333

# %%
1 + 2 + 3
# Out:
# 6

# %%
a = 1
b = 7
a / b
# Out:
# 0.14285714285714285

# %% [markdown]
# 機械学習をしよう

# %% [markdown]
# # 機械学習をしよう

# %% [markdown]
# ## 1.4 TensorFlow のインストール

# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.7.0'
